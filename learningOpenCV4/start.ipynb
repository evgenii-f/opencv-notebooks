# %%
import cv2
import numpy as np
import re
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = np.zeros((3, 3), dtype=np.uint8)
img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
_
# Out:
# ''

# %%
imgpath = r"C:\Users\evgenii.fedorov\Pictures\spiderman.png"
img_grey = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
img = cv2.imread(imgpath)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img)
cv2.imwrite(re.sub('spiderman', 'spiderman_grey', imgpath), img_grey)
# Out:
# True

# %%
img.item(1,2, 2) == img[1, 2, 2]
# Out:
# True

# %%
img.shape
# Out:
# (850, 940, 3)

# %%
my_roi = img[100:300, 100:300]
img[0:200, 0:200] = my_roi
plt.imshow(img)

# %%
cv2.imshow('test', img)
cv2.waitKey()
cv2.destroyAllWindows()
